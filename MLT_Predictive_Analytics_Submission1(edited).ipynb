# %% [markdown]
# <a href="https://colab.research.google.com/github/sukmasukriana/Sukma-Sukriana_Submission-1_MLT/blob/sukmasukriana-patch-1-submission1/MLT_Predictive_Analytics_Submission1(edited).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Proyek Machine Learning : Predictive Analytics
#
# * Domain : Ekonomi dan Pendidikan
# * Tujuan : Melakukan Prediksi pendapatan(**salary**) Lulusan Bahasa Inggris di Turki
# * Dataset yang digunakan : https://www.kaggle.com/datasets/cagrigungor/turkey-teacher-salary-and-minimum-salary/code

# %% [markdown]
# ## Melakukan Import terhadap Library yang diperlukan

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.metrics import mean_squared_error
from pandas import read_csv

# %% [markdown]
# ## DATA UNDERSTANDING

# %% [markdown]
# ### Memuat Dataset ***turkish_salary.csv*** pada variabel **"df"**

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('turkish_salary.csv')

# Display basic information about the dataset
print(df.info())

# Display descriptive statistics
print(df.describe())

import pandas as pd

# Load dataset
df = pd.read_csv('turkish_salary.csv')

# Display basic information about the dataset
print(df.info())

# Display descriptive statistics
print(df.describe())

import pandas as pd

# Load dataset
df = pd.read_csv('turkish_salary.csv')

# Display basic information about the dataset
print(df.info())

# Display descriptive statistics
print(df.describe())

# Visualize data using histograms and scatter plots
df.hist()
pd.plotting.scatter_matrix(df)
# Display basic information about the dataset
print(df.info())

# Display descriptive statistics
print(df.describe())

# Visualize data using histograms and scatter plots
df.hist()
pd.plotting.scatter_matrix(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      21 non-null     int64
#  1   year            21 non-null     int64
#  2   teacher         21 non-null     float64
#  3   mininum_salary  21 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 800.0 bytes
# None
#        Unnamed: 0         year      teacher  mininum_salary
# count   21.000000    21.000000    21.000000       21.000000
# mean    10.000000  2012.000000  2819.715238     1156.285714
# std      6.204837     6.204837  2080.068004     1233.003696
# min      0.000000  2002.000000   635.200000      163.000000
# 25%      5.000000  2007.000000  1261.000000      403.000000
# 50%     10.000000  2012.000000  2276.000000      701.000000
# 75%     15.000000  2017.000000  3618.000000     1404.000000
# max     20.000000  2022.000000  8600.000000     5500.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      21 non-null     int64
#  1   year            21 non-null     int64
#  2   teacher         21 non-null     float64
#  3   mininum_salary  21 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 800.0 bytes
# None
#        Unnamed: 0         year      teacher  mininum_salary
# count   21.000000    21.000000    21.000000       21.000000
# mean    10.000000  2012.000000  2819.715238     1156.285714
# std      6.204837     6.204837  2080.068004     1233.003696
# min      0.000000  2002.000000   635.200000      163.000000
# 25%      5.000000  2007.000000  1261.000000      403.000000
# 50%     10.000000  2012.000000  2276.000000      701.000000
# 75%     15.000000  2017.000000  3618.000000     1404.000000
# max     20.000000  2022.000000  8600.000000     5500.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      21 non-null     int64
#  1   year            21 non-null     int64
#  2   teacher         21 non-null     float64
#  3   mininum_salary  21 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 800.0 bytes
# None
#        Unnamed: 0         year      teacher  mininum_salary
# count   21.000000    21.000000    21.000000       21.000000
# mean    10.000000  2012.000000  2819.715238     1156.285714
# std      6.204837     6.204837  2080.068004     1233.003696
# min      0.000000  2002.000000   635.200000      163.000000
# 25%      5.000000  2007.000000  1261.000000      403.000000
# 50%     10.000000  2012.000000  2276.000000      701.000000
# 75%     15.000000  2017.000000  3618.000000     1404.000000
# max     20.000000  2022.000000  8600.000000     5500.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      21 non-null     int64
#  1   year            21 non-null     int64
#  2   teacher         21 non-null     float64
#  3   mininum_salary  21 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 800.0 bytes
# None
#        Unnamed: 0         year      teacher  mininum_salary
# count   21.000000    21.000000    21.000000       21.000000
# mean    10.000000  2012.000000  2819.715238     1156.285714
# std      6.204837     6.204837  2080.068004     1233.003696
# min      0.000000  2002.000000   635.200000      163.000000
# 25%      5.000000  2007.000000  1261.000000      403.000000
# 50%     10.000000  2012.000000  2276.000000      701.000000
# 75%     15.000000  2017.000000  3618.000000     1404.000000
# max     20.000000  2022.000000  8600.000000     5500.000000
# array([[<Axes: xlabel='Unnamed: 0', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='year', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='teacher', ylabel='Unnamed: 0'>,
#         <Axes: xlabel='mininum_salary', ylabel='Unnamed: 0'>],
#        [<Axes: xlabel='Unnamed: 0', ylabel='year'>,
#         <Axes: xlabel='year', ylabel='year'>,
#         <Axes: xlabel='teacher', ylabel='year'>,
#         <Axes: xlabel='mininum_salary', ylabel='year'>],
#        [<Axes: xlabel='Unnamed: 0', ylabel='teacher'>,
#         <Axes: xlabel='year', ylabel='teacher'>,
#         <Axes: xlabel='teacher', ylabel='teacher'>,
#         <Axes: xlabel='mininum_salary', ylabel='teacher'>],
#        [<Axes: xlabel='Unnamed: 0', ylabel='mininum_salary'>,
#         <Axes: xlabel='year', ylabel='mininum_salary'>,
#         <Axes: xlabel='teacher', ylabel='mininum_salary'>,
#         <Axes: xlabel='mininum_salary', ylabel='mininum_salary'>]],
#       dtype=object)

# %% [markdown]
# ### Menampilkan tipe data setiap kolom pada dataset "df"

# %%
import pandas as pd

# Load dataset
df = pd.read_csv('turkish_salary.csv')

# Display basic information about the dataset
print(df.info())

# Display descriptive statistics
print(df.describe())

# Visualize data using histograms and scatter plots
df.hist()
pd.plotting.scatter_matrix(df)
# Display basic information about the dataset
print(df.info())

# Display descriptive statistics
print(df.describe())

# Visualize data using histograms and scatter plots
df.hist()
pd.plotting.scatter_matrix(df)

# Get the list of existing columns in the DataFrame
existing_columns = df.columns.tolist()

# Define the columns to drop
columns_to_drop = ['', 'year', '#teacher', '#minimum_salary']
columns_to_drop = [col for col in columns_to_drop if col in existing_columns]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      21 non-null     int64
#  1   year            21 non-null     int64
#  2   teacher         21 non-null     float64
#  3   mininum_salary  21 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 800.0 bytes
# None
#        Unnamed: 0         year      teacher  mininum_salary
# count   21.000000    21.000000    21.000000       21.000000
# mean    10.000000  2012.000000  2819.715238     1156.285714
# std      6.204837     6.204837  2080.068004     1233.003696
# min      0.000000  2002.000000   635.200000      163.000000
# 25%      5.000000  2007.000000  1261.000000      403.000000
# 50%     10.000000  2012.000000  2276.000000      701.000000
# 75%     15.000000  2017.000000  3618.000000     1404.000000
# max     20.000000  2022.000000  8600.000000     5500.000000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      21 non-null     int64
#  1   year            21 non-null     int64
#  2   teacher         21 non-null     float64
#  3   mininum_salary  21 non-null     int64
# dtypes: float64(1), int64(3)
# memory usage: 800.0 bytes
# None
#        Unnamed: 0         year      teacher  mininum_salary
# count   21.000000    21.000000    21.000000       21.000000
# mean    10.000000  2012.000000  2819.715238     1156.285714
# std      6.204837     6.204837  2080.068004     1233.003696
# min      0.000000  2002.000000   635.200000      163.000000
# 25%      5.000000  2007.000000  1261.000000      403.000000
# 50%     10.000000  2012.000000  2276.000000      701.000000
# 75%     15.000000  2017.000000  3618.000000     1404.000000
# max     20.000000  2022.000000  8600.000000     5500.000000

# %%
if columns_to_drop:
    df.drop(columns=columns_to_drop, inplace=True)

# %% [markdown]
# ### Menghapus(**drop**) kolom/fitur yang tidak diperlukan

# %% [markdown]
# ### Menampilkan tipe data setiap kolom pada dataset "df" setelah proses ***drop***

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21 entries, 0 to 20
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      21 non-null     int64
#  1   teacher         21 non-null     float64
#  2   mininum_salary  21 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 632.0 bytes

# %% [markdown]
# ###  Deskripsi Variabel Numerik

# %%
df.describe()
# Out:
#        Unnamed: 0      teacher  mininum_salary
# count   21.000000    21.000000       21.000000
# mean    10.000000  2819.715238     1156.285714
# std      6.204837  2080.068004     1233.003696
# min      0.000000   635.200000      163.000000
# 25%      5.000000  1261.000000      403.000000
# 50%     10.000000  2276.000000      701.000000
# 75%     15.000000  3618.000000     1404.000000
# max     20.000000  8600.000000     5500.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['teacher'].plot(kind='hist', bins=20, title='teacher')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['mininum_salary'].plot(kind='hist', bins=20, title='mininum_salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_3.plot(kind='scatter', x='Unnamed: 0', y='teacher', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='teacher', y='mininum_salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['teacher'].plot(kind='line', figsize=(8, 4), title='teacher')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7['mininum_salary'].plot(kind='line', figsize=(8, 4), title='mininum_salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Unnamed: 0'].plot(kind='hist', bins=20, title='Unnamed: 0')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['teacher'].plot(kind='hist', bins=20, title='teacher')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['mininum_salary'].plot(kind='hist', bins=20, title='mininum_salary')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_11.groupby('index').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12.plot(kind='scatter', x='Unnamed: 0', y='teacher', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13.plot(kind='scatter', x='teacher', y='mininum_salary', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_14['Unnamed: 0'].plot(kind='line', figsize=(8, 4), title='Unnamed: 0')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['teacher'].plot(kind='line', figsize=(8, 4), title='teacher')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_16['mininum_salary'].plot(kind='line', figsize=(8, 4), title='mininum_salary')
# plt.gca().spines[['top', 'right']].set_visible(False)
# <h4 class="colab-quickchart-section-title">Faceted distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_17['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_17, x='Unnamed: 0', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_18['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_18, x='teacher', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)
# <string>:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
# from matplotlib import pyplot as plt
# import seaborn as sns
# figsize = (12, 1.2 * len(_df_19['index'].unique()))
# plt.figure(figsize=figsize)
# sns.violinplot(_df_19, x='mininum_salary', y='index', inner='stick', palette='Dark2')
# sns.despine(top=True, right=True, bottom=True, left=True)

# %% [markdown]
# ### Mendapatkan ukuran(***shape***) dari dataset

# %%
df.shape
# Out:
# (21, 3)

# %% [markdown]
# ### Melakukan pemeriksaan terhadap nilai yang hilang(***missing value***) pada dataset

# %%
df.isnull().sum()
# Out:
# Unnamed: 0        0
# teacher           0
# mininum_salary    0
# dtype: int64

# %% [markdown]
# ### Memvisualisasikan data menggunakan ***boxplot*** untuk fitur numerik:
# <ul>
#   <li>[]</li>
#   <li>[year]</li>
#   <li>[teacher]</li>
#   <li>[minimum_salary]</li>
#
#
#
# </ul>

# %%
import numpy as np # imports the numpy library and assigns it to the alias np
import matplotlib.pyplot as plt
import seaborn as sns

for column in df.select_dtypes(include=np.number).columns:  # Select only numerical features
    plt.figure(figsize=(8, 6))  # Adjust figure size if needed
    sns.boxplot(x=df[column])
    plt.title(f'Boxplot of {column}')
    plt.show()

# %% [markdown]
# ### Mengatasi masalah ***outlier*** dengan Metode IQR

# %%
Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3-Q1
df=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %% [markdown]
# ### Menampilkan ukuran dataset setelah ***outliers*** diatasi

# %%
df.shape
# Out:
# (20, 3)

# %% [markdown]
# ### Menampilkan tipe data setiap kolom pada dataset "df" setelah proses ***outliers*** diatasi

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      20 non-null     int64
#  1   teacher         20 non-null     float64
#  2   mininum_salary  20 non-null     int64
# dtypes: float64(1), int64(2)
# memory usage: 640.0 bytes

# %% [markdown]
# ### Menganalisa data menggunakan Univariate Analysis

# %% [markdown]
# #### Membagi fitur numerik dan kategorik yang terdapat pada dataset ####

# %%
numeric_feature = [' ', 'year', '#teacher', '#minimum_salary']




category_feature = ['Integer', 'Decimal']

# %% [markdown]
# ### Menganalisa data menggunakan Multivariate Analysis

# %%
# fitur kategori dan numerik
category = df.select_dtypes(include='object').columns.to_list()

for col in category:
  sns.catplot(x=col, y="Salary", kind="bar", dodge=False, height = 4,
              aspect = 5, data=df, palette="Set3")

# %% [markdown]
# ### Menampilkan Plot Pair fitur numerik

# %%
sns.pairplot(df, diag_kind='kde')

# %% [markdown]
# ### Melakukan pengamatan terhadap tingkat korelasi dengan menggunakan matrik korelasi pada tiap fitur

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr().round(2)

sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', linewidth=0.5)
plt.title("Matrik Korelasi fitur numerik", size=20)
# Out:
# Text(0.5, 1.0, 'Matrik Korelasi fitur numerik')

# %% [markdown]
# ### Menghapus fitur yang nilai tingkat korelasinya lemah
#
# <ul type="none">
#   <li>Semakin dekat nilainya ke 0, korelasinya semakin lemah</li>
# </ul>

# %%
# Get the list of existing columns in the DataFrame
existing_columns = df.columns.tolist()

# Define the columns to drop
columns_to_drop = ['', 'year', '#teacher', '#minimum_salary']

# Only drop columns that actually exist in the DataFrame
columns_to_drop = [col for col in columns_to_drop if col in existing_columns]

# Now, drop the columns safely
if columns_to_drop:  # Check if there are any columns to drop
    df.drop(columns=columns_to_drop, inplace=True, axis=1)

# %% [markdown]
# ### Menampilkan dataset "df" setelah proses drop

# %%
df
# Out:
#     Unnamed: 0  teacher  mininum_salary
# 0            0   635.20             163
# 1            1   734.00             225
# 2            2   831.82             303
# 3            3   909.00             350
# 4            4  1133.00             380
# 5            5  1261.00             403
# 6            6  1560.00             481
# 7            7  1699.00             527
# 8            8  1808.00             576
# 9            9  2049.00             629
# 10          10  2276.00             701
# 11          11  2437.00             773
# 12          12  2693.00             846
# 13          13  2926.00             949
# 14          14  3288.00            1300
# 15          15  3618.00            1404
# 16          16  4153.00            1603
# 17          17  4890.00            2020
# 18          18  5213.00            2324
# 19          19  6500.00            2825

# %% [markdown]
# ### Menampilkan kembali matrik korelasi fitur numerik

# %%
plt.figure(figsize=(10, 8))
correlation_matrix = df.corr().round(2)

sns.heatmap(data=correlation_matrix, annot=True, cmap='coolwarm', linewidth=0.5)
plt.title("Matrik Korelasi fitur numerik", size=20)
# Out:
# Text(0.5, 1.0, 'Matrik Korelasi fitur numerik')

# %% [markdown]
# ## DATA PREPARATION

# %% [markdown]
# ### Encoding Fitur Kategorik ###

# %%
# Create dummy variables for categorical features
# Check if the column exists before applying get_dummies
if 'year' in df.columns:
    df = pd.concat([df, pd.get_dummies(df['year'], prefix='year', drop_first=True)], axis=1)
if 'teacher' in df.columns:
    df = pd.concat([df, pd.get_dummies(df['teacher'], prefix='teacher', drop_first=True)], axis=1)
if 'minimum salary' in df.columns:
    df = pd.concat([df, pd.get_dummies(df['minimum salary'], prefix='minimum salary', drop_first=True)], axis=1)

# %%
# Create dummy variables for categorical features
# Check if the column exists before applying get_dummies
if 'year' in df.columns:
    df = pd.concat([df, pd.get_dummies(df['year'], prefix='year', drop_first=True)], axis=1)
if 'teacher' in df.columns:
    df = pd.concat([df, pd.get_dummies(df['teacher'], prefix='teacher', drop_first=True)], axis=1)
if 'minimum salary' in df.columns:
    df = pd.concat([df, pd.get_dummies(df['minimum salary'], prefix='minimum salary', drop_first=True)], axis=1)

# %% [markdown]
# ### Menampilkan dataset ***df*** setelah proses ***Encoding***

# %%
df
# Out:
#     Unnamed: 0  teacher  mininum_salary
# 0            0   635.20             163
# 1            1   734.00             225
# 2            2   831.82             303
# 3            3   909.00             350
# 4            4  1133.00             380
# 5            5  1261.00             403
# 6            6  1560.00             481
# 7            7  1699.00             527
# 8            8  1808.00             576
# 9            9  2049.00             629
# 10          10  2276.00             701
# 11          11  2437.00             773
# 12          12  2693.00             846
# 13          13  2926.00             949
# 14          14  3288.00            1300
# 15          15  3618.00            1404
# 16          16  4153.00            1603
# 17          17  4890.00            2020
# 18          18  5213.00            2324
# 19          19  6500.00            2825

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1hsiBet23f_YVfMSyk3RaDxfoKzBljtYuIsAjXQq45rk#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1hsiBet23f_YVfMSyk3RaDxfoKzBljtYuIsAjXQq45rk#gid=0/edit?rm=embedded?usp=sharing?widget=true&amp;headers=false"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Menampilkan dataset ***df*** setelah proses reduksi dimensi

# %%
df
# Out:
#     Unnamed: 0  teacher  mininum_salary  teacher_734.0  teacher_831.82  \
# 0            0   635.20             163          False           False
# 1            1   734.00             225           True           False
# 2            2   831.82             303          False            True
# 3            3   909.00             350          False           False
# 4            4  1133.00             380          False           False
# 5            5  1261.00             403          False           False
# 6            6  1560.00             481          False           False
# 7            7  1699.00             527          False           False
# 8            8  1808.00             576          False           False
# 9            9  2049.00             629          False           False
# 10          10  2276.00             701          False           False
# 11          11  2437.00             773          False           False
# 12          12  2693.00             846          False           False
# 13          13  2926.00             949          False           False
# 14          14  3288.00            1300          False           False
# 15          15  3618.00            1404          False           False
# 16          16  4153.00            1603          False           False
# 17          17  4890.00            2020          False           False
# 18          18  5213.00            2324          False           False
# 19          19  6500.00            2825          False           False
#
#     teacher_909.0  teacher_1133.0  teacher_1261.0  teacher_1560.0  \
# 0           False           False           False           False
# 1           False           False           False           False
# 2           False           False           False           False
# 3            True           False           False           False
# 4           False            True           False           False
# 5           False           False            True           False
# 6           False           False           False            True
# 7           False           False           False           False
# 8           False           False           False           False
# 9           False           False           False           False
# 10          False           False           False           False
# 11          False           False           False           False
# 12          False           False           False           False
# 13          False           False           False           False
# 14          False           False           False           False
# 15          False           False           False           False
# 16          False           False           False           False
# 17          False           False           False           False
# 18          False           False           False           False
# 19          False           False           False           False
#
#     teacher_1699.0  ...  teacher_2276.0  teacher_2437.0  teacher_2693.0  \
# 0            False  ...           False           False           False
# 1            False  ...           False           False           False
# 2            False  ...           False           False           False
# 3            False  ...           False           False           False
# 4            False  ...           False           False           False
# 5            False  ...           False           False           False
# 6            False  ...           False           False           False
# 7             True  ...           False           False           False
# 8            False  ...           False           False           False
# 9            False  ...           False           False           False
# 10           False  ...            True           False           False
# 11           False  ...           False            True           False
# 12           False  ...           False           False            True
# 13           False  ...           False           False           False
# 14           False  ...           False           False           False
# 15           False  ...           False           False           False
# 16           False  ...           False           False           False
# 17           False  ...           False           False           False
# 18           False  ...           False           False           False
# 19           False  ...           False           False           False
#
#     teacher_2926.0  teacher_3288.0  teacher_3618.0  teacher_4153.0  \
# 0            False           False           False           False
# 1            False           False           False           False
# 2            False           False           False           False
# 3            False           False           False           False
# 4            False           False           False           False
# 5            False           False           False           False
# 6            False           False           False           False
# 7            False           False           False           False
# 8            False           False           False           False
# 9            False           False           False           False
# 10           False           False           False           False
# 11           False           False           False           False
# 12           False           False           False           False
# 13            True           False           False           False
# 14           False            True           False           False
# 15           False           False            True           False
# 16           False           False           False            True
# 17           False           False           False           False
# 18           False           False           False           False
# 19           False           False           False           False
#
#     teacher_4890.0  teacher_5213.0  teacher_6500.0
# 0            False           False           False
# 1            False           False           False
# 2            False           False           False
# 3            False           False           False
# 4            False           False           False
# 5            False           False           False
# 6            False           False           False
# 7            False           False           False
# 8            False           False           False
# 9            False           False           False
# 10           False           False           False
# 11           False           False           False
# 12           False           False           False
# 13           False           False           False
# 14           False           False           False
# 15           False           False           False
# 16           False           False           False
# 17            True           False           False
# 18           False            True           False
# 19           False           False            True
#
# [20 rows x 41 columns]

# %% [markdown]
# ## MODEL DEVELOPMENT

# %% [markdown]
# ### Menyiapkan dataframe untuk analisa model

# %%
models = pd.DataFrame(
    index=['train_mse', 'test_mse'],
    columns=['KNN', 'RandomForest', 'Boosting']
)

# %% [markdown]
# ## EVALUASI MODEL
#
# <ul type="none" align="justify">
#   <li>
#   Secara umum, jika nilai prediksi mendekati nilai sebenarnya, performanya baik. Sedangkan jika tidak, performanya buruk. Secara teknis, selisih antara nilai sebenarnya dan nilai prediksi disebut eror. Maka, semua metrik mengukur seberapa kecil nilai eror tersebut.
#   </li>
# </ul>

# %% [markdown]
# ### Mengevaluasi ketiga model prediksi dengan metrik MSE
#
# <ul type="none" align="justify">
#   <li>
# Metrik yang gunakan pada prediksi ini adalah MSE(Mean Squared Error) yang menghitung jumlah selisih kuadrat rata-rata nilai sebenarnya dengan nilai prediksi.
#   </li>
# </ul>

# %%
mse = pd.DataFrame(columns=['train', 'test'], index=['KNN', 'RF', 'Boosting'])
model_dict = {'KNN': KNN, 'RF': RF, 'Boosting':boosting}

for name, model in model_dict.items():
  mse.loc[name, 'train'] = mean_squared_error(y_true=y_train, y_pred=model.predict(X_train))/1e6
  mse.loc[name, 'test'] = mean_squared_error(y_true=y_test, y_pred=model.predict(X_test))/1e6

# Data metrik MSE
mse
# Out:
#             train     test
# KNN       15185.5  23380.6
# RF        15468.2  20335.8
# Boosting  13995.9  21734.2

# %% [markdown]
# ### Membuat Plot metrik MSE dengan bar chart

# %%
fig, ax = plt.subplots()
mse.sort_values(by='test', ascending=False).plot(kind='barh', ax=ax, zorder=3)
ax.grid(zorder=0)

# %% [markdown]
# ### Pengujian model prediksi menggunakan nilai ***Salary*** dari dataset

# %%
prediksi = X_test.iloc[:1].copy()
pred_dict = {'Salary':y_test[:1]}

for name, model in model_dict.items():
  pred_dict['prediksi_'+name] = model.predict(prediksi).round(1)

pd.DataFrame(pred_dict)
# Out:
#       Salary  prediksi_KNN  prediksi_RF  prediksi_Boosting
# 1399  300000      244700.0     282445.4           260123.3

# %% [markdown]
# ## KESIMPULAN
# <ul type="none" align="justify">
#   <li>
# Pengujian setiap model dengan algoritma yang berbeda menghasilkan nilai prediksi yang berbeda pula. Model dengan nilai yang mendekati nilai sebenarnya diperoleh pada prediksi dengan menggunakan algoritma Random Forest. Untuk
# prediksi menggunakan algoritma K-Nearest Neighbor dan Boosting, performanya masih dibawah prediksi model Random Forest. Sehingga dapat disimpulkan bahwa pada kasus ini, model dengan menggunakan Algoritma Random Forest lebih tepat untuk digunakan atau diterapkan.
#   </li>
# </ul>
